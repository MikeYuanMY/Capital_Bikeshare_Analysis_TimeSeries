# %%
import numpy as np
import pandas as pd
import pandas_profiling
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-663d244bf639> in <module>
#       2 import numpy as np
#       3 import pandas as pd
# ----> 4 import pandas_profiling
#
# ModuleNotFoundError: No module named 'pandas_profiling'

# %%
data = pd.read_csv("../data/Bike-Sharing-Dataset/day.csv")

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-0a63388c6925> in <module>
# ----> 1 data.profile_report()
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'profile_report'

# %%
#!pip install pandas-profiling -U

# %%
df = pd.DataFrame(
    np.random.rand(100, 5),
    columns=['a', 'b', 'c', 'd', 'e']
)

# %%
dates = pd.to_datetime(data.dteday)
data.set_index(dates)
# Out:
#             instant      dteday  season  yr  mnth  holiday  weekday  \
# dteday
# 2011-01-01        1  2011-01-01       1   0     1        0        6
# 2011-01-02        2  2011-01-02       1   0     1        0        0
# 2011-01-03        3  2011-01-03       1   0     1        0        1
# 2011-01-04        4  2011-01-04       1   0     1        0        2
# 2011-01-05        5  2011-01-05       1   0     1        0        3
# 2011-01-06        6  2011-01-06       1   0     1        0        4
# 2011-01-07        7  2011-01-07       1   0     1        0        5
# 2011-01-08        8  2011-01-08       1   0     1        0        6
# 2011-01-09        9  2011-01-09       1   0     1        0        0
# 2011-01-10       10  2011-01-10       1   0     1        0        1
# 2011-01-11       11  2011-01-11       1   0     1        0        2
# 2011-01-12       12  2011-01-12       1   0     1        0        3
# 2011-01-13       13  2011-01-13       1   0     1        0        4
# ...

# %%
import altair as alt
alt.renderers.enable('notebook')
# Out:
# RendererRegistry.enable('notebook')

# %%
data['date']= data.index

# %%
chart = alt.Chart(data)

# %%
casual_plot = chart.mark_line().encode(
    x = "dteday",
    y = "casual"
)

# %%
casual_plot

# %%
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# 5          6  2011-01-06       1   0     1        0        4           1
# 6          7  2011-01-07       1   0     1        0        5           1
# 7          8  2011-01-08       1   0     1        0        6           0
# 8          9  2011-01-09       1   0     1        0        0           0
# 9         10  2011-01-10       1   0     1        0        1           1
# 10        11  2011-01-11       1   0     1        0        2           1
# 11        12  2011-01-12       1   0     1        0        3           1
# ...
